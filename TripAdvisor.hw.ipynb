# %% [markdown]
# # Identify:
#
# Please fill-in your ID in the following cell, **only id numbers, no names!**

# %%
id1 = "207256835"

# %%
import pandas as pd
df = pd.DataFrame([id1])

# %% [markdown]
# Uncomment in case two students are doing the assignment together:

# %%
#df = pd.DataFrame([id1,id2])

# %%
df.to_clipboard(index=False,header=False)

# %% [markdown]
# Please fill your names here:

# %% [markdown]
# ---

# %% [markdown]
# ----

# %% [markdown]
# # Write your answers here
#
# add as much lines of code and markdown as you need for each answer

# %% [markdown]
# # Q1

# %%
import pandas as pd
import numpy as np

# %%
url = "https://raw.githubusercontent.com/nlihin/data-analytics/main/datasets/TripAdvisor_Bangkok.csv"
trip_advisor_df = pd.read_csv(url)

# %%
trip_advisor_df
# Out:
#              hotel_name  average_score             user_name  \
# 0       @Home Phetkasem            4.0                 Pat C
# 1       @Home Phetkasem            4.0                Shukki
# 2       @Home Residence            4.0            GlowSilver
# 3       @Home Residence            4.0   Ashraful Amin Robin
# 4       @Home Residence            4.0               Raoul K
# 5    101 Holiday Suites            3.5         NYC_Big_Apple
# 6    101 Holiday Suites            3.5              daniel a
# 7    101 Holiday Suites            3.5           Paulellwood
# 8    101 Holiday Suites            3.5             Cyclivist
# 9   103 - Bed and Brews            4.0             gixernick
# 10  103 - Bed and Brews            4.0             Hibee1965
# 11  103 - Bed and Brews            4.0                kris m
# 12  103 - Bed and Brews            4.0            Carolyn822
# 13  103 - Bed and Brews            4.0           John Andrew
# ...

# %%
trip_advisor_df['review_score'] = trip_advisor_df['review_score']/10

# %%
trip_advisor_df.hist('review_score')
# Out:
# array([[<AxesSubplot:title={'center':'review_score'}>]], dtype=object)

# %% [markdown]
#  # Q2

# %%
trip_advisor_df.boxplot(column=['year'], fontsize=15, patch_artist=True)
# Out:
# <AxesSubplot:>

# %%
trip_advisor_df = trip_advisor_df[trip_advisor_df['year'] < 2022].reset_index(drop=True)
trip_advisor_df.boxplot(column=['year'], fontsize=15, patch_artist=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Q3

# %%
trip_advisor_df[['review_score','average_score']].plot.hist(alpha=0.4)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # Q4

# %%
trip_advisor_df.boxplot(column=['average_score','review_score'],  fontsize=15)
# Out:
# <AxesSubplot:>

# %% [markdown]
# the median is the same for both score
#
# the range is wider for the review score, since there is less data for review_score  (@Shai A.: it doesn't matter what they answer here. Q was just to get the students to think. don't reduct points for the explanation in words)

# %% [markdown]
# הסיבה להבדלים בין הציונים היא מכיוון שהממוצע ציונים מראה את ממוצע כל הציונים שהמשתמשים נתנו בטריפ אדווייזר וציוני הסקירה מראים את התפלגות הציונים של המשתמש.

# %% [markdown]
# # Q5

# %%
trip_advisor_df.groupby(['month'])[['review_score']].count().sort_values(by='review_score', ascending=False)
# Out:
#        review_score
# month
# 1             15311
# 12            12701
# 2             12642
# 3             11296
# 11            11093
# 10            10462
# 8             10030
# 7              9754
# 9              9486
# 4              8569
# 5              8240
# 6              7991

# %% [markdown]
# # Q6

# %%
trip_advisor_df.groupby(['month'])[['review_score']].mean().sort_values('review_score', ascending = False)
# Out:
#        review_score
# month
# 10         4.140031
# 2          4.076966
# 9          4.066308
# 11         4.055531
# 12         4.049445
# 1          4.031154
# 3          4.020627
# 7          4.014046
# 8          4.002193
# 6          4.001627
# 5          3.962743
# 4          3.940717

# %% [markdown]
# # Q7

# %%
mean_reviews= trip_advisor_df.groupby(['hotel_name','year'])[['review_score']].mean()
mean = mean_reviews.sort_values(by='review_score', ascending=False)
mean.loc[mean.review_score == 1].head(5)
# Out:
#                                        review_score
# hotel_name                       year
# Ozone Hotel Samyan               2019           1.0
# PR Place Hotel and Apartment     2018           1.0
# Mido Hotel                       2012           1.0
# KT Place                         2013           1.0
# Win Long Place Hotel & Apartment 2017           1.0

# %% [markdown]
# # Q8

# %%
mean.hist('review_score')
# Out:
# array([[<AxesSubplot:title={'center':'review_score'}>]], dtype=object)

# %% [markdown]
# ההסטוגרמה שונה מההסטוגרמה המוצגת בשאלה מספר 1 מכיוון שההסטוגרמה הנוכחית מראה את ממוצע ציוני הסקירה של המשתמשים, בשונה מההסטוגרמה שהוצגה בשאלה 1 שמראה את ציוני הסקירה של המשתמשים בין 0-5

# %% [markdown]
# ---
# # GOOD LUCK !!!!
# ---

# %%
# do not type below this line
